# %% [markdown]
# ### HW # 3
# Student name: Olha Tanyuk

# %% [markdown]
# 1.	Compare your given name with your nickname (if you don’t have a nickname, invent one for this assignment) by answering the following questions:
#
# a.	What is the edit distance between your nickname and your given name?
#
# b.	What is the percentage string match between your nickname and your given name?
# Show your work for both calculations.
# 2.	Find a friend (or family member or classmate) who you know has read a certain book. Without your friend knowing, copy the first two sentences of that book. Now rewrite the words from those sentences, excluding stop words. Now tell your friend to guess which book the words are from by reading them just that list of words. Did you friend correctly guess the book on the first try? What did he or she guess? Explain why you think you friend either was or was not able to guess the book from hearing the list of words.
#
# 3.	Run one of the stemmers available in Python. Run the same two sentences from question 2 above through the stemmer and show the results. How many of the outputted stems are valid morphological roots of the corresponding words? Express this answer as a percentage.

# %% [markdown]
# ## 1.

# %%
import re
import nltk
from nltk import edit_distance
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.corpus import words

from nltk.stem.snowball import SnowballStemmer

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\otany\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
name = "Olha"
nick = "alloha"

# %%
edit_distance(name, nick)
# Out:
# 3

# %% [markdown]
# a) The edit distance between my nickname and my given name is 3.
# Seems about right: my given name and nickname share some letters.

# %%
print(len(name))
print(len(nick))
# Out:
# 4
# 6

# %%
from difflib import SequenceMatcher

def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()*100
        
print("Name and nickname are {:.2f}% similar.".format(similar(name, nick)))
# Out:
# Name and nickname are 60.00% similar.

# %% [markdown]
# b) 60% string match between my nickname and my given name.

# %% [markdown]
# ## 2.

# %%
sentence = "In the beginning God created the heaven and the earth. And the earth was without form, and void; and darkness was upon the face of the deep. And the Spirit of God moved upon the face of the waters. And God said, Let there be light: and there was light."

# %% [markdown]
# Those sentences were taken from the book of Genesis, found in the Christian bible. I know an individual who has read that book.

# %%
tokens = [i for i in re.split("[^a-zA-z]", sentence) if not re.search("[^a-zA-z]", i) and len(i) > 0]

sentence_nostop = [word for word in word_tokenize(sentence) if word.lower() not in stopwords.words("english")]

# %%
" ".join(sentence_nostop)
# Out:
# 'beginning God created heaven earth . earth without form , void ; darkness upon face deep . Spirit God moved upon face waters . God said , Let light : light .'

# %% [markdown]
# My friend was able to guess the book from hearing the list of words from 1st try. The first 5 words have made a good hint what a book was used in this test:  "beginning God created heaven earth".

# %% [markdown]
# ## 3.

# %%
all_words = set(words.words())

# %%
all_words
# Out:
# {'rascalism',
#  'flickery',
#  'Danic',
#  'workpeople',
#  'potpie',
#  'sexarticulate',
#  'houndish',
#  'Haemulidae',
#  'Machicui',
#  'saltarella',
#  'Gamelion',
#  'neurocoele',
#  'heirless',
#  'overtop',
#  'retree',
#  'septimole',
#  'undeceptive',
#  'peltatifid',
#  'battel',
#  'spherocrystal',
#  'crapy',
#  'tobaccoman',
#  'counterfeitly',
#  'oversetter',
#  'Urticales',
#  'flocoon',
#  'peridentoclasia',
#  'springing',
#  'gobline',
#  'pulverant',
#  'marinated',
#  'subdate',
#  'Bryonia',
#  'contingently',
#  'kenoticist',
#  'Saba',
#  'huck',
#  'auspicial',
#  'torfaceous',
#  'patchable',
#  'xylotypographic',
#  'perturbing',
#  'radiometeorograph',
#  'shuffling',
#  'photoperiodic',
#  'electrodialyzer',
#  'demilion',
#  'untapering',
#  'decimalize',
#  'crinanite',
#  'quinton',
#  'genteelism',
#  'questionist',
#  'scrappily',
#  'hornety',
#  'relinquisher',
#  'ushabtiu',
#  'happily',
#  'managerially',
#  'Pantagruel',
#  'sheepshear',
# ...

# %%
print(tokens)
# Out:
# ['In', 'the', 'beginning', 'God', 'created', 'the', 'heaven', 'and', 'the', 'earth', 'And', 'the', 'earth', 'was', 'without', 'form', 'and', 'void', 'and', 'darkness', 'was', 'upon', 'the', 'face', 'of', 'the', 'deep', 'And', 'the', 'Spirit', 'of', 'God', 'moved', 'upon', 'the', 'face', 'of', 'the', 'waters', 'And', 'God', 'said', 'Let', 'there', 'be', 'light', 'and', 'there', 'was', 'light']

# %%
Snowball = SnowballStemmer("english")
s_stems = [Snowball.stem(i) for i in tokens]

valid_counts = 0

for i in s_stems:
    if i in all_words:
        valid_counts += 1
    
frmt = "{:.2f}% of the outputted stems are valid morphological roots of the corresponding words using a Snowball Stemmer."

print(frmt.format(valid_counts / len(s_stems)*100))
# Out:
# 100.00% of the outputted stems are valid morphological roots of the corresponding words using a Snowball Stemmer.
